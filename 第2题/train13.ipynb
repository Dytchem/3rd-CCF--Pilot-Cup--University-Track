# %%
from utils import *
import numpy as np
import matplotlib.pyplot as plt
import pyqpanda as pq
import pyvqnet as pv
import random

# %matplotlib inline

# %%
train_data = Dataset(
    "data/cifar-10-batches-py/data_batch_1",
    "data/cifar-10-batches-py/data_batch_2",
    "data/cifar-10-batches-py/data_batch_3",
    "data/cifar-10-batches-py/data_batch_4",
    "data/cifar-10-batches-py/data_batch_5",
)
train_data.enhance()
test_data = Dataset("data/cifar-10-batches-py/test_batch")

# %%
obs_list = [
    {
        "wires": [i],
        "observables": ["Z"],
        "coefficient": [1],
    }
    for i in range(10)
]


def pqc(input, param, qubits, cbits, machine):
    n = len(input)
    prog = pq.QProg()
    prog.insert(pq.H(qubits[10]))
    for i in range(10):
        prog.insert(pq.CNOT(qubits[10], qubits[i]))
    for i in range(n):
        prog.insert(pq.U2(qubits[i % 10], param[i], input[i]))
    for i in range(10):
        prog.insert(pq.CNOT(qubits[10], qubits[i]))

    re = pv.qnn.measure.MeasurePauliSum(machine, prog, obs_list, qubits)
    return re


class Model(pv.nn.module.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = pv.nn.Conv2D(3, 30, (3, 3))
        self.conv2 = pv.nn.Conv2D(30, 30, (3, 3))
        self.pool2 = pv.nn.MaxPool2D((2, 2), (2, 2))
        self.conv3 = pv.nn.Conv2D(30, 30, (3, 3))
        self.conv4 = pv.nn.Conv2D(30, 30, (3, 3))
        self.pool4 = pv.nn.MaxPool2D((2, 2), (2, 2))
        self.conv5 = pv.nn.Conv2D(30, 30, (3, 3))
        self.conv6 = pv.nn.Conv2D(30, 30, (3, 3))
        self.qc = pv.qnn.quantumlayer.QuantumLayer(
            pqc, 30, "CPU", 11, diff_method="finite_diff"
        )
        # self.qc = pv.nn.Linear(30, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.pool2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.pool4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = pv.tensor.flatten(x, 1)
        x = 2 * pv.tensor.atan(x)
        x = self.qc(x)
        return x

# %%
epoch = 100
batch = 16
holdout = 10000

model = Model()
print(sum(p.numel() for p in model.parameters()))
# Out:
# 41520

# %%
X, Y = train_data.getdatas()
los = pv.nn.loss.CrossEntropyLoss()
opt = pv.optim.SGD(model.parameters())

acc_train = []
acc_test = []

for e in range(1, epoch + 1):
    model.train()

    correct_tot = 0
    for I, (x, y) in enumerate(
        pv.data.data_generator(
            X[:-holdout], Y[:-holdout], batch_size=batch, shuffle=True
        )
    ):
        i = I + 1
        # print(i)
        opt.zero_grad()
        y_pred = model(x)
        loss = los(y, y_pred)
        correct = sum(y_pred.argmax(1, False).to_numpy() == y)
        acc = correct / y.shape[0]
        correct_tot += correct
        loss.backward()
        opt._step()
        if i % 10 == 0:
            print(
                f"epoch {e}/{epoch} \t batch {batch*i}/{Y.shape[0]-holdout} \t loss {loss.item():.2f} \t accuracy {acc:.2f}"
            )

    model.eval()

    acc = correct_tot / (Y.shape[0] - holdout)
    print(f"********** train: epoch {e}/{epoch} \t accuracy {100*acc:.2f}% **********")
    acc_train.append(acc)

    correct_tot = 0
    for x, y in pv.data.data_generator(
        X[-holdout:], Y[-holdout:], batch_size=batch, shuffle=False
    ):
        y_pred = model(x)
        correct_tot += sum(y_pred.argmax(1, False).to_numpy() == y)

    acc = correct_tot / holdout
    print(f"********** test: epoch {e}/{epoch} \t accuracy {100*acc:.2f}% **********")
    acc_test.append(acc)

    opt = pv.optim.SGD(model.parameters(), 0.01 * (1 - acc))
# Out:
# epoch 1/100 	 batch 160/90000 	 loss 2.39 	 accuracy 0.06
# epoch 1/100 	 batch 320/90000 	 loss 2.33 	 accuracy 0.12
# epoch 1/100 	 batch 480/90000 	 loss 2.46 	 accuracy 0.00
# epoch 1/100 	 batch 640/90000 	 loss 2.21 	 accuracy 0.38
# epoch 1/100 	 batch 800/90000 	 loss 2.30 	 accuracy 0.12
# epoch 1/100 	 batch 960/90000 	 loss 2.32 	 accuracy 0.19
# epoch 1/100 	 batch 1120/90000 	 loss 2.27 	 accuracy 0.06
# epoch 1/100 	 batch 1280/90000 	 loss 2.22 	 accuracy 0.31
# epoch 1/100 	 batch 1440/90000 	 loss 2.35 	 accuracy 0.00
# epoch 1/100 	 batch 1600/90000 	 loss 2.27 	 accuracy 0.12
# epoch 1/100 	 batch 1760/90000 	 loss 2.30 	 accuracy 0.00
# epoch 1/100 	 batch 1920/90000 	 loss 2.29 	 accuracy 0.12
# epoch 1/100 	 batch 2080/90000 	 loss 2.33 	 accuracy 0.12
# epoch 1/100 	 batch 2240/90000 	 loss 2.24 	 accuracy 0.25
# epoch 1/100 	 batch 2400/90000 	 loss 2.23 	 accuracy 0.25
# epoch 1/100 	 batch 2560/90000 	 loss 2.36 	 accuracy 0.06
# epoch 1/100 	 batch 2720/90000 	 loss 2.28 	 accuracy 0.06
# epoch 1/100 	 batch 2880/90000 	 loss 2.34 	 accuracy 0.12
# epoch 1/100 	 batch 3040/90000 	 loss 2.28 	 accuracy 0.06
# epoch 1/100 	 batch 3200/90000 	 loss 2.35 	 accuracy 0.06
# epoch 1/100 	 batch 3360/90000 	 loss 2.24 	 accuracy 0.06
# epoch 1/100 	 batch 3520/90000 	 loss 2.32 	 accuracy 0.00
# epoch 1/100 	 batch 3680/90000 	 loss 2.27 	 accuracy 0.12
# epoch 1/100 	 batch 3840/90000 	 loss 2.19 	 accuracy 0.25
# epoch 1/100 	 batch 4000/90000 	 loss 2.23 	 accuracy 0.19
# epoch 1/100 	 batch 4160/90000 	 loss 2.34 	 accuracy 0.00
# epoch 1/100 	 batch 4320/90000 	 loss 2.27 	 accuracy 0.06
# epoch 1/100 	 batch 4480/90000 	 loss 2.25 	 accuracy 0.25
# epoch 1/100 	 batch 4640/90000 	 loss 2.23 	 accuracy 0.19
# epoch 1/100 	 batch 4800/90000 	 loss 2.25 	 accuracy 0.31
# epoch 1/100 	 batch 4960/90000 	 loss 2.29 	 accuracy 0.12
# epoch 1/100 	 batch 5120/90000 	 loss 2.24 	 accuracy 0.38
# epoch 1/100 	 batch 5280/90000 	 loss 2.23 	 accuracy 0.12
# epoch 1/100 	 batch 5440/90000 	 loss 2.21 	 accuracy 0.25
# epoch 1/100 	 batch 5600/90000 	 loss 2.25 	 accuracy 0.19
# epoch 1/100 	 batch 5760/90000 	 loss 2.16 	 accuracy 0.38
# epoch 1/100 	 batch 5920/90000 	 loss 2.29 	 accuracy 0.12
# epoch 1/100 	 batch 6080/90000 	 loss 2.17 	 accuracy 0.19
# epoch 1/100 	 batch 6240/90000 	 loss 2.17 	 accuracy 0.19
# epoch 1/100 	 batch 6400/90000 	 loss 2.16 	 accuracy 0.25
# epoch 1/100 	 batch 6560/90000 	 loss 2.31 	 accuracy 0.31
# epoch 1/100 	 batch 6720/90000 	 loss 2.09 	 accuracy 0.38
# epoch 1/100 	 batch 6880/90000 	 loss 2.13 	 accuracy 0.19
# epoch 1/100 	 batch 7040/90000 	 loss 2.13 	 accuracy 0.31
# epoch 1/100 	 batch 7200/90000 	 loss 2.27 	 accuracy 0.00
# epoch 1/100 	 batch 7360/90000 	 loss 2.18 	 accuracy 0.06
# epoch 1/100 	 batch 7520/90000 	 loss 2.21 	 accuracy 0.12
# epoch 1/100 	 batch 7680/90000 	 loss 1.98 	 accuracy 0.38
# epoch 1/100 	 batch 7840/90000 	 loss 2.23 	 accuracy 0.19
# epoch 1/100 	 batch 8000/90000 	 loss 2.13 	 accuracy 0.06
# epoch 1/100 	 batch 8160/90000 	 loss 1.98 	 accuracy 0.44
# epoch 1/100 	 batch 8320/90000 	 loss 2.15 	 accuracy 0.19
# epoch 1/100 	 batch 8480/90000 	 loss 2.03 	 accuracy 0.19
# epoch 1/100 	 batch 8640/90000 	 loss 2.03 	 accuracy 0.31
# epoch 1/100 	 batch 8800/90000 	 loss 2.03 	 accuracy 0.19
# epoch 1/100 	 batch 8960/90000 	 loss 2.07 	 accuracy 0.25
# epoch 1/100 	 batch 9120/90000 	 loss 1.79 	 accuracy 0.50
# epoch 1/100 	 batch 9280/90000 	 loss 1.96 	 accuracy 0.19
# epoch 1/100 	 batch 9440/90000 	 loss 2.15 	 accuracy 0.06
# epoch 1/100 	 batch 9600/90000 	 loss 2.11 	 accuracy 0.38
# epoch 1/100 	 batch 9760/90000 	 loss 1.92 	 accuracy 0.25
# epoch 1/100 	 batch 9920/90000 	 loss 2.16 	 accuracy 0.19
# epoch 1/100 	 batch 10080/90000 	 loss 2.24 	 accuracy 0.12
# epoch 1/100 	 batch 10240/90000 	 loss 2.21 	 accuracy 0.06
# epoch 1/100 	 batch 10400/90000 	 loss 1.98 	 accuracy 0.50
# epoch 1/100 	 batch 10560/90000 	 loss 2.05 	 accuracy 0.25
# epoch 1/100 	 batch 10720/90000 	 loss 2.09 	 accuracy 0.31
# epoch 1/100 	 batch 10880/90000 	 loss 2.09 	 accuracy 0.31
# epoch 1/100 	 batch 11040/90000 	 loss 2.27 	 accuracy 0.12
# epoch 1/100 	 batch 11200/90000 	 loss 2.12 	 accuracy 0.38
# epoch 1/100 	 batch 11360/90000 	 loss 2.09 	 accuracy 0.38
# epoch 1/100 	 batch 11520/90000 	 loss 2.02 	 accuracy 0.12
# epoch 1/100 	 batch 11680/90000 	 loss 2.05 	 accuracy 0.12
# epoch 1/100 	 batch 11840/90000 	 loss 2.00 	 accuracy 0.38
# epoch 1/100 	 batch 12000/90000 	 loss 2.19 	 accuracy 0.12
# epoch 1/100 	 batch 12160/90000 	 loss 1.95 	 accuracy 0.38
# epoch 1/100 	 batch 12320/90000 	 loss 2.10 	 accuracy 0.12
# epoch 1/100 	 batch 12480/90000 	 loss 1.97 	 accuracy 0.19
# epoch 1/100 	 batch 12640/90000 	 loss 1.97 	 accuracy 0.44
# epoch 1/100 	 batch 12800/90000 	 loss 1.90 	 accuracy 0.25
# epoch 1/100 	 batch 12960/90000 	 loss 2.17 	 accuracy 0.12
# epoch 1/100 	 batch 13120/90000 	 loss 2.21 	 accuracy 0.19
# epoch 1/100 	 batch 13280/90000 	 loss 1.96 	 accuracy 0.38
# epoch 1/100 	 batch 13440/90000 	 loss 2.10 	 accuracy 0.31
# epoch 1/100 	 batch 13600/90000 	 loss 2.12 	 accuracy 0.31
# epoch 1/100 	 batch 13760/90000 	 loss 2.24 	 accuracy 0.12
# epoch 1/100 	 batch 13920/90000 	 loss 2.02 	 accuracy 0.25
# epoch 1/100 	 batch 14080/90000 	 loss 2.10 	 accuracy 0.25
# epoch 1/100 	 batch 14240/90000 	 loss 2.11 	 accuracy 0.25
# epoch 1/100 	 batch 14400/90000 	 loss 2.05 	 accuracy 0.19
# epoch 1/100 	 batch 14560/90000 	 loss 2.05 	 accuracy 0.44
# epoch 1/100 	 batch 14720/90000 	 loss 2.01 	 accuracy 0.25
# epoch 1/100 	 batch 14880/90000 	 loss 2.03 	 accuracy 0.31
# epoch 1/100 	 batch 15040/90000 	 loss 2.07 	 accuracy 0.31
# epoch 1/100 	 batch 15200/90000 	 loss 1.91 	 accuracy 0.38
# epoch 1/100 	 batch 15360/90000 	 loss 2.21 	 accuracy 0.31
# epoch 1/100 	 batch 15520/90000 	 loss 2.06 	 accuracy 0.44
# epoch 1/100 	 batch 15680/90000 	 loss 1.97 	 accuracy 0.12
# epoch 1/100 	 batch 15840/90000 	 loss 1.72 	 accuracy 0.50
# epoch 1/100 	 batch 16000/90000 	 loss 1.96 	 accuracy 0.25
# epoch 1/100 	 batch 16160/90000 	 loss 2.19 	 accuracy 0.12
# epoch 1/100 	 batch 16320/90000 	 loss 2.02 	 accuracy 0.19
# epoch 1/100 	 batch 16480/90000 	 loss 1.84 	 accuracy 0.38
# epoch 1/100 	 batch 16640/90000 	 loss 1.96 	 accuracy 0.44
# epoch 1/100 	 batch 16800/90000 	 loss 2.12 	 accuracy 0.31
# epoch 1/100 	 batch 16960/90000 	 loss 1.96 	 accuracy 0.19
# epoch 1/100 	 batch 17120/90000 	 loss 2.05 	 accuracy 0.31
# epoch 1/100 	 batch 17280/90000 	 loss 2.08 	 accuracy 0.25
# epoch 1/100 	 batch 17440/90000 	 loss 1.79 	 accuracy 0.25
# epoch 1/100 	 batch 17600/90000 	 loss 1.95 	 accuracy 0.25
# epoch 1/100 	 batch 17760/90000 	 loss 1.93 	 accuracy 0.44
# epoch 1/100 	 batch 17920/90000 	 loss 2.15 	 accuracy 0.25
# epoch 1/100 	 batch 18080/90000 	 loss 2.02 	 accuracy 0.19
# epoch 1/100 	 batch 18240/90000 	 loss 2.08 	 accuracy 0.19
# epoch 1/100 	 batch 18400/90000 	 loss 2.04 	 accuracy 0.06
# epoch 1/100 	 batch 18560/90000 	 loss 1.96 	 accuracy 0.31
# epoch 1/100 	 batch 18720/90000 	 loss 1.96 	 accuracy 0.31
# epoch 1/100 	 batch 18880/90000 	 loss 1.89 	 accuracy 0.44
# epoch 1/100 	 batch 19040/90000 	 loss 2.08 	 accuracy 0.44
# epoch 1/100 	 batch 19200/90000 	 loss 2.15 	 accuracy 0.19
# epoch 1/100 	 batch 19360/90000 	 loss 1.99 	 accuracy 0.31
# epoch 1/100 	 batch 19520/90000 	 loss 2.00 	 accuracy 0.31
# epoch 1/100 	 batch 19680/90000 	 loss 2.04 	 accuracy 0.25
# epoch 1/100 	 batch 19840/90000 	 loss 1.99 	 accuracy 0.19
# epoch 1/100 	 batch 20000/90000 	 loss 2.12 	 accuracy 0.12
# epoch 1/100 	 batch 20160/90000 	 loss 1.84 	 accuracy 0.31
# epoch 1/100 	 batch 20320/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 20480/90000 	 loss 2.08 	 accuracy 0.12
# epoch 1/100 	 batch 20640/90000 	 loss 2.24 	 accuracy 0.00
# epoch 1/100 	 batch 20800/90000 	 loss 1.89 	 accuracy 0.12
# epoch 1/100 	 batch 20960/90000 	 loss 2.11 	 accuracy 0.25
# epoch 1/100 	 batch 21120/90000 	 loss 2.07 	 accuracy 0.25
# epoch 1/100 	 batch 21280/90000 	 loss 1.88 	 accuracy 0.31
# epoch 1/100 	 batch 21440/90000 	 loss 2.00 	 accuracy 0.44
# epoch 1/100 	 batch 21600/90000 	 loss 2.03 	 accuracy 0.38
# epoch 1/100 	 batch 21760/90000 	 loss 1.93 	 accuracy 0.31
# epoch 1/100 	 batch 21920/90000 	 loss 2.06 	 accuracy 0.25
# epoch 1/100 	 batch 22080/90000 	 loss 1.90 	 accuracy 0.25
# epoch 1/100 	 batch 22240/90000 	 loss 1.90 	 accuracy 0.38
# epoch 1/100 	 batch 22400/90000 	 loss 2.02 	 accuracy 0.31
# epoch 1/100 	 batch 22560/90000 	 loss 2.24 	 accuracy 0.12
# epoch 1/100 	 batch 22720/90000 	 loss 1.84 	 accuracy 0.25
# epoch 1/100 	 batch 22880/90000 	 loss 2.14 	 accuracy 0.19
# epoch 1/100 	 batch 23040/90000 	 loss 1.95 	 accuracy 0.19
# epoch 1/100 	 batch 23200/90000 	 loss 1.91 	 accuracy 0.25
# epoch 1/100 	 batch 23360/90000 	 loss 1.95 	 accuracy 0.31
# epoch 1/100 	 batch 23520/90000 	 loss 2.22 	 accuracy 0.25
# epoch 1/100 	 batch 23680/90000 	 loss 2.18 	 accuracy 0.25
# epoch 1/100 	 batch 23840/90000 	 loss 1.89 	 accuracy 0.50
# epoch 1/100 	 batch 24000/90000 	 loss 1.88 	 accuracy 0.31
# epoch 1/100 	 batch 24160/90000 	 loss 2.06 	 accuracy 0.38
# epoch 1/100 	 batch 24320/90000 	 loss 1.94 	 accuracy 0.38
# epoch 1/100 	 batch 24480/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 24640/90000 	 loss 1.96 	 accuracy 0.44
# epoch 1/100 	 batch 24800/90000 	 loss 1.93 	 accuracy 0.50
# epoch 1/100 	 batch 24960/90000 	 loss 1.98 	 accuracy 0.38
# epoch 1/100 	 batch 25120/90000 	 loss 2.06 	 accuracy 0.38
# epoch 1/100 	 batch 25280/90000 	 loss 1.91 	 accuracy 0.19
# epoch 1/100 	 batch 25440/90000 	 loss 1.95 	 accuracy 0.25
# epoch 1/100 	 batch 25600/90000 	 loss 2.20 	 accuracy 0.25
# epoch 1/100 	 batch 25760/90000 	 loss 1.66 	 accuracy 0.56
# epoch 1/100 	 batch 25920/90000 	 loss 2.10 	 accuracy 0.25
# epoch 1/100 	 batch 26080/90000 	 loss 2.14 	 accuracy 0.31
# epoch 1/100 	 batch 26240/90000 	 loss 1.82 	 accuracy 0.44
# epoch 1/100 	 batch 26400/90000 	 loss 1.93 	 accuracy 0.31
# epoch 1/100 	 batch 26560/90000 	 loss 1.79 	 accuracy 0.31
# epoch 1/100 	 batch 26720/90000 	 loss 1.94 	 accuracy 0.31
# epoch 1/100 	 batch 26880/90000 	 loss 1.77 	 accuracy 0.44
# epoch 1/100 	 batch 27040/90000 	 loss 2.00 	 accuracy 0.25
# epoch 1/100 	 batch 27200/90000 	 loss 1.99 	 accuracy 0.25
# epoch 1/100 	 batch 27360/90000 	 loss 1.78 	 accuracy 0.44
# epoch 1/100 	 batch 27520/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 27680/90000 	 loss 2.02 	 accuracy 0.44
# epoch 1/100 	 batch 27840/90000 	 loss 1.76 	 accuracy 0.38
# epoch 1/100 	 batch 28000/90000 	 loss 1.83 	 accuracy 0.44
# epoch 1/100 	 batch 28160/90000 	 loss 1.73 	 accuracy 0.50
# epoch 1/100 	 batch 28320/90000 	 loss 2.09 	 accuracy 0.31
# epoch 1/100 	 batch 28480/90000 	 loss 1.95 	 accuracy 0.25
# epoch 1/100 	 batch 28640/90000 	 loss 1.75 	 accuracy 0.56
# epoch 1/100 	 batch 28800/90000 	 loss 1.91 	 accuracy 0.38
# epoch 1/100 	 batch 28960/90000 	 loss 1.85 	 accuracy 0.31
# epoch 1/100 	 batch 29120/90000 	 loss 1.90 	 accuracy 0.25
# epoch 1/100 	 batch 29280/90000 	 loss 1.95 	 accuracy 0.38
# epoch 1/100 	 batch 29440/90000 	 loss 1.81 	 accuracy 0.56
# epoch 1/100 	 batch 29600/90000 	 loss 2.07 	 accuracy 0.31
# epoch 1/100 	 batch 29760/90000 	 loss 2.11 	 accuracy 0.25
# epoch 1/100 	 batch 29920/90000 	 loss 2.09 	 accuracy 0.19
# epoch 1/100 	 batch 30080/90000 	 loss 1.87 	 accuracy 0.38
# epoch 1/100 	 batch 30240/90000 	 loss 1.58 	 accuracy 0.56
# epoch 1/100 	 batch 30400/90000 	 loss 2.13 	 accuracy 0.19
# epoch 1/100 	 batch 30560/90000 	 loss 2.03 	 accuracy 0.25
# epoch 1/100 	 batch 30720/90000 	 loss 2.06 	 accuracy 0.12
# epoch 1/100 	 batch 30880/90000 	 loss 1.84 	 accuracy 0.44
# epoch 1/100 	 batch 31040/90000 	 loss 1.84 	 accuracy 0.44
# epoch 1/100 	 batch 31200/90000 	 loss 2.04 	 accuracy 0.31
# epoch 1/100 	 batch 31360/90000 	 loss 1.94 	 accuracy 0.12
# epoch 1/100 	 batch 31520/90000 	 loss 1.92 	 accuracy 0.38
# epoch 1/100 	 batch 31680/90000 	 loss 2.02 	 accuracy 0.38
# epoch 1/100 	 batch 31840/90000 	 loss 1.94 	 accuracy 0.31
# epoch 1/100 	 batch 32000/90000 	 loss 1.89 	 accuracy 0.44
# epoch 1/100 	 batch 32160/90000 	 loss 2.05 	 accuracy 0.25
# epoch 1/100 	 batch 32320/90000 	 loss 1.89 	 accuracy 0.31
# epoch 1/100 	 batch 32480/90000 	 loss 1.86 	 accuracy 0.25
# epoch 1/100 	 batch 32640/90000 	 loss 2.20 	 accuracy 0.25
# epoch 1/100 	 batch 32800/90000 	 loss 2.04 	 accuracy 0.31
# epoch 1/100 	 batch 32960/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 33120/90000 	 loss 2.24 	 accuracy 0.12
# epoch 1/100 	 batch 33280/90000 	 loss 1.83 	 accuracy 0.38
# epoch 1/100 	 batch 33440/90000 	 loss 1.95 	 accuracy 0.25
# epoch 1/100 	 batch 33600/90000 	 loss 2.10 	 accuracy 0.31
# epoch 1/100 	 batch 33760/90000 	 loss 1.79 	 accuracy 0.38
# epoch 1/100 	 batch 33920/90000 	 loss 1.81 	 accuracy 0.38
# epoch 1/100 	 batch 34080/90000 	 loss 2.13 	 accuracy 0.25
# epoch 1/100 	 batch 34240/90000 	 loss 2.12 	 accuracy 0.25
# epoch 1/100 	 batch 34400/90000 	 loss 1.80 	 accuracy 0.56
# epoch 1/100 	 batch 34560/90000 	 loss 2.12 	 accuracy 0.25
# epoch 1/100 	 batch 34720/90000 	 loss 1.87 	 accuracy 0.38
# epoch 1/100 	 batch 34880/90000 	 loss 1.85 	 accuracy 0.31
# epoch 1/100 	 batch 35040/90000 	 loss 1.92 	 accuracy 0.38
# epoch 1/100 	 batch 35200/90000 	 loss 1.70 	 accuracy 0.31
# epoch 1/100 	 batch 35360/90000 	 loss 1.82 	 accuracy 0.31
# epoch 1/100 	 batch 35520/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 35680/90000 	 loss 1.83 	 accuracy 0.38
# epoch 1/100 	 batch 35840/90000 	 loss 1.97 	 accuracy 0.12
# epoch 1/100 	 batch 36000/90000 	 loss 1.93 	 accuracy 0.31
# epoch 1/100 	 batch 36160/90000 	 loss 2.02 	 accuracy 0.12
# epoch 1/100 	 batch 36320/90000 	 loss 1.86 	 accuracy 0.12
# epoch 1/100 	 batch 36480/90000 	 loss 2.24 	 accuracy 0.12
# epoch 1/100 	 batch 36640/90000 	 loss 1.97 	 accuracy 0.50
# epoch 1/100 	 batch 36800/90000 	 loss 1.87 	 accuracy 0.38
# epoch 1/100 	 batch 36960/90000 	 loss 1.75 	 accuracy 0.38
# epoch 1/100 	 batch 37120/90000 	 loss 1.75 	 accuracy 0.31
# epoch 1/100 	 batch 37280/90000 	 loss 1.92 	 accuracy 0.25
# epoch 1/100 	 batch 37440/90000 	 loss 1.88 	 accuracy 0.50
# epoch 1/100 	 batch 37600/90000 	 loss 1.82 	 accuracy 0.31
# epoch 1/100 	 batch 37760/90000 	 loss 1.65 	 accuracy 0.38
# epoch 1/100 	 batch 37920/90000 	 loss 2.01 	 accuracy 0.19
# epoch 1/100 	 batch 38080/90000 	 loss 1.83 	 accuracy 0.38
# epoch 1/100 	 batch 38240/90000 	 loss 1.80 	 accuracy 0.50
# epoch 1/100 	 batch 38400/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 38560/90000 	 loss 1.98 	 accuracy 0.25
# epoch 1/100 	 batch 38720/90000 	 loss 1.69 	 accuracy 0.25
# epoch 1/100 	 batch 38880/90000 	 loss 1.75 	 accuracy 0.31
# epoch 1/100 	 batch 39040/90000 	 loss 1.99 	 accuracy 0.25
# epoch 1/100 	 batch 39200/90000 	 loss 1.68 	 accuracy 0.44
# epoch 1/100 	 batch 39360/90000 	 loss 1.70 	 accuracy 0.38
# epoch 1/100 	 batch 39520/90000 	 loss 1.84 	 accuracy 0.25
# epoch 1/100 	 batch 39680/90000 	 loss 1.80 	 accuracy 0.44
# epoch 1/100 	 batch 39840/90000 	 loss 1.82 	 accuracy 0.44
# epoch 1/100 	 batch 40000/90000 	 loss 1.97 	 accuracy 0.25
# epoch 1/100 	 batch 40160/90000 	 loss 1.98 	 accuracy 0.31
# epoch 1/100 	 batch 40320/90000 	 loss 2.16 	 accuracy 0.12
# epoch 1/100 	 batch 40480/90000 	 loss 1.83 	 accuracy 0.31
# epoch 1/100 	 batch 40640/90000 	 loss 1.93 	 accuracy 0.31
# epoch 1/100 	 batch 40800/90000 	 loss 1.76 	 accuracy 0.25
# epoch 1/100 	 batch 40960/90000 	 loss 1.72 	 accuracy 0.50
# epoch 1/100 	 batch 41120/90000 	 loss 1.73 	 accuracy 0.50
# epoch 1/100 	 batch 41280/90000 	 loss 1.98 	 accuracy 0.25
# epoch 1/100 	 batch 41440/90000 	 loss 1.92 	 accuracy 0.31
# epoch 1/100 	 batch 41600/90000 	 loss 1.49 	 accuracy 0.81
# epoch 1/100 	 batch 41760/90000 	 loss 1.62 	 accuracy 0.44
# epoch 1/100 	 batch 41920/90000 	 loss 2.09 	 accuracy 0.12
# epoch 1/100 	 batch 42080/90000 	 loss 1.92 	 accuracy 0.50
# epoch 1/100 	 batch 42240/90000 	 loss 1.89 	 accuracy 0.38
# epoch 1/100 	 batch 42400/90000 	 loss 1.86 	 accuracy 0.25
# epoch 1/100 	 batch 42560/90000 	 loss 1.97 	 accuracy 0.31
# epoch 1/100 	 batch 42720/90000 	 loss 1.85 	 accuracy 0.25
# epoch 1/100 	 batch 42880/90000 	 loss 1.86 	 accuracy 0.19
# epoch 1/100 	 batch 43040/90000 	 loss 2.14 	 accuracy 0.31
# epoch 1/100 	 batch 43200/90000 	 loss 1.75 	 accuracy 0.31
# epoch 1/100 	 batch 43360/90000 	 loss 1.96 	 accuracy 0.31
# epoch 1/100 	 batch 43520/90000 	 loss 1.81 	 accuracy 0.19
# epoch 1/100 	 batch 43680/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 43840/90000 	 loss 1.99 	 accuracy 0.31
# epoch 1/100 	 batch 44000/90000 	 loss 1.81 	 accuracy 0.44
# epoch 1/100 	 batch 44160/90000 	 loss 1.89 	 accuracy 0.50
# epoch 1/100 	 batch 44320/90000 	 loss 1.90 	 accuracy 0.38
# epoch 1/100 	 batch 44480/90000 	 loss 1.80 	 accuracy 0.31
# epoch 1/100 	 batch 44640/90000 	 loss 1.84 	 accuracy 0.38
# epoch 1/100 	 batch 44800/90000 	 loss 1.84 	 accuracy 0.44
# epoch 1/100 	 batch 44960/90000 	 loss 1.58 	 accuracy 0.69
# epoch 1/100 	 batch 45120/90000 	 loss 1.96 	 accuracy 0.38
# epoch 1/100 	 batch 45280/90000 	 loss 1.80 	 accuracy 0.44
# epoch 1/100 	 batch 45440/90000 	 loss 1.88 	 accuracy 0.19
# epoch 1/100 	 batch 45600/90000 	 loss 1.89 	 accuracy 0.31
# epoch 1/100 	 batch 45760/90000 	 loss 1.91 	 accuracy 0.44
# epoch 1/100 	 batch 45920/90000 	 loss 1.87 	 accuracy 0.38
# epoch 1/100 	 batch 46080/90000 	 loss 2.13 	 accuracy 0.25
# epoch 1/100 	 batch 46240/90000 	 loss 1.93 	 accuracy 0.31
# epoch 1/100 	 batch 46400/90000 	 loss 1.91 	 accuracy 0.19
# epoch 1/100 	 batch 46560/90000 	 loss 1.89 	 accuracy 0.38
# epoch 1/100 	 batch 46720/90000 	 loss 1.71 	 accuracy 0.50
# epoch 1/100 	 batch 46880/90000 	 loss 1.66 	 accuracy 0.44
# epoch 1/100 	 batch 47040/90000 	 loss 1.87 	 accuracy 0.06
# epoch 1/100 	 batch 47200/90000 	 loss 1.83 	 accuracy 0.19
# epoch 1/100 	 batch 47360/90000 	 loss 1.81 	 accuracy 0.38
# epoch 1/100 	 batch 47520/90000 	 loss 1.63 	 accuracy 0.56
# epoch 1/100 	 batch 47680/90000 	 loss 1.74 	 accuracy 0.50
# epoch 1/100 	 batch 47840/90000 	 loss 1.76 	 accuracy 0.38
# epoch 1/100 	 batch 48000/90000 	 loss 1.93 	 accuracy 0.19
# epoch 1/100 	 batch 48160/90000 	 loss 1.97 	 accuracy 0.25
# epoch 1/100 	 batch 48320/90000 	 loss 1.65 	 accuracy 0.44
# epoch 1/100 	 batch 48480/90000 	 loss 1.75 	 accuracy 0.56
# epoch 1/100 	 batch 48640/90000 	 loss 1.97 	 accuracy 0.38
# epoch 1/100 	 batch 48800/90000 	 loss 2.13 	 accuracy 0.25
# epoch 1/100 	 batch 48960/90000 	 loss 1.75 	 accuracy 0.44
# epoch 1/100 	 batch 49120/90000 	 loss 1.73 	 accuracy 0.38
# epoch 1/100 	 batch 49280/90000 	 loss 1.92 	 accuracy 0.25
# epoch 1/100 	 batch 49440/90000 	 loss 1.94 	 accuracy 0.38
# epoch 1/100 	 batch 49600/90000 	 loss 1.67 	 accuracy 0.44
# epoch 1/100 	 batch 49760/90000 	 loss 1.90 	 accuracy 0.31
# epoch 1/100 	 batch 49920/90000 	 loss 1.91 	 accuracy 0.38
# epoch 1/100 	 batch 50080/90000 	 loss 1.88 	 accuracy 0.38
# epoch 1/100 	 batch 50240/90000 	 loss 2.01 	 accuracy 0.38
# epoch 1/100 	 batch 50400/90000 	 loss 1.72 	 accuracy 0.31
# epoch 1/100 	 batch 50560/90000 	 loss 1.94 	 accuracy 0.31
# epoch 1/100 	 batch 50720/90000 	 loss 1.95 	 accuracy 0.44
# epoch 1/100 	 batch 50880/90000 	 loss 2.06 	 accuracy 0.31
# epoch 1/100 	 batch 51040/90000 	 loss 1.86 	 accuracy 0.38
# epoch 1/100 	 batch 51200/90000 	 loss 1.81 	 accuracy 0.38
# epoch 1/100 	 batch 51360/90000 	 loss 1.80 	 accuracy 0.31
# epoch 1/100 	 batch 51520/90000 	 loss 1.68 	 accuracy 0.50
# epoch 1/100 	 batch 51680/90000 	 loss 1.71 	 accuracy 0.25
# epoch 1/100 	 batch 51840/90000 	 loss 1.88 	 accuracy 0.44
# epoch 1/100 	 batch 52000/90000 	 loss 1.74 	 accuracy 0.56
# epoch 1/100 	 batch 52160/90000 	 loss 1.82 	 accuracy 0.31
# epoch 1/100 	 batch 52320/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 52480/90000 	 loss 1.86 	 accuracy 0.38
# epoch 1/100 	 batch 52640/90000 	 loss 1.78 	 accuracy 0.25
# epoch 1/100 	 batch 52800/90000 	 loss 1.89 	 accuracy 0.25
# epoch 1/100 	 batch 52960/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 53120/90000 	 loss 1.89 	 accuracy 0.31
# epoch 1/100 	 batch 53280/90000 	 loss 1.90 	 accuracy 0.38
# epoch 1/100 	 batch 53440/90000 	 loss 1.98 	 accuracy 0.25
# epoch 1/100 	 batch 53600/90000 	 loss 1.90 	 accuracy 0.38
# epoch 1/100 	 batch 53760/90000 	 loss 1.66 	 accuracy 0.44
# epoch 1/100 	 batch 53920/90000 	 loss 1.72 	 accuracy 0.56
# epoch 1/100 	 batch 54080/90000 	 loss 1.63 	 accuracy 0.38
# epoch 1/100 	 batch 54240/90000 	 loss 1.71 	 accuracy 0.25
# epoch 1/100 	 batch 54400/90000 	 loss 1.70 	 accuracy 0.50
# epoch 1/100 	 batch 54560/90000 	 loss 1.89 	 accuracy 0.31
# epoch 1/100 	 batch 54720/90000 	 loss 1.79 	 accuracy 0.50
# epoch 1/100 	 batch 54880/90000 	 loss 1.68 	 accuracy 0.56
# epoch 1/100 	 batch 55040/90000 	 loss 1.68 	 accuracy 0.44
# epoch 1/100 	 batch 55200/90000 	 loss 1.70 	 accuracy 0.31
# epoch 1/100 	 batch 55360/90000 	 loss 1.95 	 accuracy 0.19
# epoch 1/100 	 batch 55520/90000 	 loss 1.95 	 accuracy 0.38
# epoch 1/100 	 batch 55680/90000 	 loss 1.78 	 accuracy 0.50
# epoch 1/100 	 batch 55840/90000 	 loss 2.22 	 accuracy 0.25
# epoch 1/100 	 batch 56000/90000 	 loss 1.77 	 accuracy 0.38
# epoch 1/100 	 batch 56160/90000 	 loss 1.76 	 accuracy 0.38
# epoch 1/100 	 batch 56320/90000 	 loss 1.79 	 accuracy 0.56
# epoch 1/100 	 batch 56480/90000 	 loss 1.70 	 accuracy 0.44
# epoch 1/100 	 batch 56640/90000 	 loss 1.77 	 accuracy 0.50
# epoch 1/100 	 batch 56800/90000 	 loss 1.77 	 accuracy 0.44
# epoch 1/100 	 batch 56960/90000 	 loss 1.93 	 accuracy 0.38
# epoch 1/100 	 batch 57120/90000 	 loss 1.77 	 accuracy 0.50
# epoch 1/100 	 batch 57280/90000 	 loss 2.06 	 accuracy 0.25
# epoch 1/100 	 batch 57440/90000 	 loss 1.73 	 accuracy 0.50
# epoch 1/100 	 batch 57600/90000 	 loss 2.07 	 accuracy 0.31
# epoch 1/100 	 batch 57760/90000 	 loss 1.77 	 accuracy 0.44
# epoch 1/100 	 batch 57920/90000 	 loss 1.73 	 accuracy 0.56
# epoch 1/100 	 batch 58080/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 58240/90000 	 loss 1.85 	 accuracy 0.38
# epoch 1/100 	 batch 58400/90000 	 loss 1.71 	 accuracy 0.38
# epoch 1/100 	 batch 58560/90000 	 loss 1.77 	 accuracy 0.38
# epoch 1/100 	 batch 58720/90000 	 loss 2.03 	 accuracy 0.25
# epoch 1/100 	 batch 58880/90000 	 loss 1.57 	 accuracy 0.75
# epoch 1/100 	 batch 59040/90000 	 loss 1.73 	 accuracy 0.50
# epoch 1/100 	 batch 59200/90000 	 loss 1.92 	 accuracy 0.38
# epoch 1/100 	 batch 59360/90000 	 loss 2.20 	 accuracy 0.19
# epoch 1/100 	 batch 59520/90000 	 loss 1.69 	 accuracy 0.50
# epoch 1/100 	 batch 59680/90000 	 loss 1.66 	 accuracy 0.38
# epoch 1/100 	 batch 59840/90000 	 loss 1.72 	 accuracy 0.31
# epoch 1/100 	 batch 60000/90000 	 loss 1.69 	 accuracy 0.56
# epoch 1/100 	 batch 60160/90000 	 loss 1.76 	 accuracy 0.25
# epoch 1/100 	 batch 60320/90000 	 loss 1.69 	 accuracy 0.50
# epoch 1/100 	 batch 60480/90000 	 loss 1.78 	 accuracy 0.31
# epoch 1/100 	 batch 60640/90000 	 loss 2.03 	 accuracy 0.19
# epoch 1/100 	 batch 60800/90000 	 loss 2.03 	 accuracy 0.25
# epoch 1/100 	 batch 60960/90000 	 loss 1.91 	 accuracy 0.25
# epoch 1/100 	 batch 61120/90000 	 loss 1.94 	 accuracy 0.56
# epoch 1/100 	 batch 61280/90000 	 loss 1.89 	 accuracy 0.31
# epoch 1/100 	 batch 61440/90000 	 loss 1.76 	 accuracy 0.44
# epoch 1/100 	 batch 61600/90000 	 loss 1.92 	 accuracy 0.31
# epoch 1/100 	 batch 61760/90000 	 loss 1.79 	 accuracy 0.25
# epoch 1/100 	 batch 61920/90000 	 loss 2.16 	 accuracy 0.25
# epoch 1/100 	 batch 62080/90000 	 loss 1.84 	 accuracy 0.44
# epoch 1/100 	 batch 62240/90000 	 loss 1.83 	 accuracy 0.44
# epoch 1/100 	 batch 62400/90000 	 loss 1.89 	 accuracy 0.12
# epoch 1/100 	 batch 62560/90000 	 loss 1.89 	 accuracy 0.19
# epoch 1/100 	 batch 62720/90000 	 loss 1.87 	 accuracy 0.38
# epoch 1/100 	 batch 62880/90000 	 loss 1.83 	 accuracy 0.38
# epoch 1/100 	 batch 63040/90000 	 loss 1.96 	 accuracy 0.19
# epoch 1/100 	 batch 63200/90000 	 loss 1.71 	 accuracy 0.38
# epoch 1/100 	 batch 63360/90000 	 loss 2.12 	 accuracy 0.06
# epoch 1/100 	 batch 63520/90000 	 loss 1.97 	 accuracy 0.38
# epoch 1/100 	 batch 63680/90000 	 loss 1.87 	 accuracy 0.25
# epoch 1/100 	 batch 63840/90000 	 loss 1.89 	 accuracy 0.19
# epoch 1/100 	 batch 64000/90000 	 loss 1.82 	 accuracy 0.31
# epoch 1/100 	 batch 64160/90000 	 loss 2.05 	 accuracy 0.19
# epoch 1/100 	 batch 64320/90000 	 loss 1.75 	 accuracy 0.19
# epoch 1/100 	 batch 64480/90000 	 loss 1.94 	 accuracy 0.38
# epoch 1/100 	 batch 64640/90000 	 loss 1.83 	 accuracy 0.44
# epoch 1/100 	 batch 64800/90000 	 loss 1.81 	 accuracy 0.38
# epoch 1/100 	 batch 64960/90000 	 loss 1.78 	 accuracy 0.31
# epoch 1/100 	 batch 65120/90000 	 loss 1.68 	 accuracy 0.62
# epoch 1/100 	 batch 65280/90000 	 loss 1.93 	 accuracy 0.38
# epoch 1/100 	 batch 65440/90000 	 loss 1.96 	 accuracy 0.31
# epoch 1/100 	 batch 65600/90000 	 loss 1.75 	 accuracy 0.38
# epoch 1/100 	 batch 65760/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 65920/90000 	 loss 2.14 	 accuracy 0.19
# epoch 1/100 	 batch 66080/90000 	 loss 1.97 	 accuracy 0.12
# epoch 1/100 	 batch 66240/90000 	 loss 1.88 	 accuracy 0.25
# epoch 1/100 	 batch 66400/90000 	 loss 1.71 	 accuracy 0.38
# epoch 1/100 	 batch 66560/90000 	 loss 1.73 	 accuracy 0.50
# epoch 1/100 	 batch 66720/90000 	 loss 1.75 	 accuracy 0.31
# epoch 1/100 	 batch 66880/90000 	 loss 1.72 	 accuracy 0.31
# epoch 1/100 	 batch 67040/90000 	 loss 1.65 	 accuracy 0.44
# epoch 1/100 	 batch 67200/90000 	 loss 1.88 	 accuracy 0.25
# epoch 1/100 	 batch 67360/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 67520/90000 	 loss 1.93 	 accuracy 0.31
# epoch 1/100 	 batch 67680/90000 	 loss 1.91 	 accuracy 0.31
# epoch 1/100 	 batch 67840/90000 	 loss 1.81 	 accuracy 0.50
# epoch 1/100 	 batch 68000/90000 	 loss 1.63 	 accuracy 0.44
# epoch 1/100 	 batch 68160/90000 	 loss 1.71 	 accuracy 0.44
# epoch 1/100 	 batch 68320/90000 	 loss 1.90 	 accuracy 0.44
# epoch 1/100 	 batch 68480/90000 	 loss 1.96 	 accuracy 0.38
# epoch 1/100 	 batch 68640/90000 	 loss 1.74 	 accuracy 0.38
# epoch 1/100 	 batch 68800/90000 	 loss 1.75 	 accuracy 0.50
# epoch 1/100 	 batch 68960/90000 	 loss 1.70 	 accuracy 0.44
# epoch 1/100 	 batch 69120/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 69280/90000 	 loss 1.68 	 accuracy 0.38
# epoch 1/100 	 batch 69440/90000 	 loss 1.88 	 accuracy 0.38
# epoch 1/100 	 batch 69600/90000 	 loss 1.68 	 accuracy 0.31
# epoch 1/100 	 batch 69760/90000 	 loss 1.67 	 accuracy 0.69
# epoch 1/100 	 batch 69920/90000 	 loss 2.06 	 accuracy 0.31
# epoch 1/100 	 batch 70080/90000 	 loss 2.05 	 accuracy 0.19
# epoch 1/100 	 batch 70240/90000 	 loss 1.73 	 accuracy 0.38
# epoch 1/100 	 batch 70400/90000 	 loss 1.96 	 accuracy 0.38
# epoch 1/100 	 batch 70560/90000 	 loss 1.85 	 accuracy 0.31
# epoch 1/100 	 batch 70720/90000 	 loss 1.92 	 accuracy 0.44
# epoch 1/100 	 batch 70880/90000 	 loss 1.90 	 accuracy 0.38
# epoch 1/100 	 batch 71040/90000 	 loss 1.73 	 accuracy 0.38
# epoch 1/100 	 batch 71200/90000 	 loss 1.82 	 accuracy 0.31
# epoch 1/100 	 batch 71360/90000 	 loss 1.96 	 accuracy 0.31
# epoch 1/100 	 batch 71520/90000 	 loss 1.73 	 accuracy 0.31
# epoch 1/100 	 batch 71680/90000 	 loss 1.87 	 accuracy 0.44
# epoch 1/100 	 batch 71840/90000 	 loss 1.76 	 accuracy 0.50
# epoch 1/100 	 batch 72000/90000 	 loss 1.78 	 accuracy 0.38
# epoch 1/100 	 batch 72160/90000 	 loss 1.69 	 accuracy 0.44
# epoch 1/100 	 batch 72320/90000 	 loss 1.95 	 accuracy 0.19
# epoch 1/100 	 batch 72480/90000 	 loss 1.92 	 accuracy 0.38
# epoch 1/100 	 batch 72640/90000 	 loss 1.54 	 accuracy 0.62
# epoch 1/100 	 batch 72800/90000 	 loss 1.63 	 accuracy 0.56
# epoch 1/100 	 batch 72960/90000 	 loss 1.75 	 accuracy 0.56
# epoch 1/100 	 batch 73120/90000 	 loss 1.99 	 accuracy 0.19
# epoch 1/100 	 batch 73280/90000 	 loss 1.79 	 accuracy 0.25
# epoch 1/100 	 batch 73440/90000 	 loss 2.00 	 accuracy 0.38
# epoch 1/100 	 batch 73600/90000 	 loss 1.63 	 accuracy 0.56
# epoch 1/100 	 batch 73760/90000 	 loss 1.74 	 accuracy 0.50
# epoch 1/100 	 batch 73920/90000 	 loss 1.75 	 accuracy 0.44
# epoch 1/100 	 batch 74080/90000 	 loss 1.64 	 accuracy 0.38
# epoch 1/100 	 batch 74240/90000 	 loss 1.60 	 accuracy 0.44
# epoch 1/100 	 batch 74400/90000 	 loss 1.75 	 accuracy 0.56
# epoch 1/100 	 batch 74560/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 74720/90000 	 loss 1.94 	 accuracy 0.31
# epoch 1/100 	 batch 74880/90000 	 loss 1.79 	 accuracy 0.56
# epoch 1/100 	 batch 75040/90000 	 loss 1.60 	 accuracy 0.56
# epoch 1/100 	 batch 75200/90000 	 loss 1.90 	 accuracy 0.25
# epoch 1/100 	 batch 75360/90000 	 loss 1.82 	 accuracy 0.31
# epoch 1/100 	 batch 75520/90000 	 loss 1.82 	 accuracy 0.44
# epoch 1/100 	 batch 75680/90000 	 loss 1.74 	 accuracy 0.44
# epoch 1/100 	 batch 75840/90000 	 loss 1.89 	 accuracy 0.25
# epoch 1/100 	 batch 76000/90000 	 loss 1.91 	 accuracy 0.31
# epoch 1/100 	 batch 76160/90000 	 loss 1.87 	 accuracy 0.44
# epoch 1/100 	 batch 76320/90000 	 loss 1.75 	 accuracy 0.38
# epoch 1/100 	 batch 76480/90000 	 loss 1.85 	 accuracy 0.38
# epoch 1/100 	 batch 76640/90000 	 loss 2.07 	 accuracy 0.31
# epoch 1/100 	 batch 76800/90000 	 loss 1.77 	 accuracy 0.44
# epoch 1/100 	 batch 76960/90000 	 loss 1.87 	 accuracy 0.31
# epoch 1/100 	 batch 77120/90000 	 loss 1.58 	 accuracy 0.50
# epoch 1/100 	 batch 77280/90000 	 loss 1.77 	 accuracy 0.31
# epoch 1/100 	 batch 77440/90000 	 loss 1.87 	 accuracy 0.25
# epoch 1/100 	 batch 77600/90000 	 loss 1.74 	 accuracy 0.25
# epoch 1/100 	 batch 77760/90000 	 loss 1.59 	 accuracy 0.62
# epoch 1/100 	 batch 77920/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 78080/90000 	 loss 1.69 	 accuracy 0.44
# epoch 1/100 	 batch 78240/90000 	 loss 1.91 	 accuracy 0.31
# epoch 1/100 	 batch 78400/90000 	 loss 1.81 	 accuracy 0.25
# epoch 1/100 	 batch 78560/90000 	 loss 1.84 	 accuracy 0.38
# epoch 1/100 	 batch 78720/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 78880/90000 	 loss 1.72 	 accuracy 0.44
# epoch 1/100 	 batch 79040/90000 	 loss 1.67 	 accuracy 0.38
# epoch 1/100 	 batch 79200/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 79360/90000 	 loss 2.07 	 accuracy 0.19
# epoch 1/100 	 batch 79520/90000 	 loss 2.22 	 accuracy 0.19
# epoch 1/100 	 batch 79680/90000 	 loss 1.78 	 accuracy 0.44
# epoch 1/100 	 batch 79840/90000 	 loss 1.82 	 accuracy 0.38
# epoch 1/100 	 batch 80000/90000 	 loss 1.86 	 accuracy 0.44
# epoch 1/100 	 batch 80160/90000 	 loss 2.00 	 accuracy 0.31
# epoch 1/100 	 batch 80320/90000 	 loss 1.78 	 accuracy 0.25
# epoch 1/100 	 batch 80480/90000 	 loss 1.69 	 accuracy 0.44
# epoch 1/100 	 batch 80640/90000 	 loss 1.66 	 accuracy 0.38
# epoch 1/100 	 batch 80800/90000 	 loss 1.90 	 accuracy 0.38
# epoch 1/100 	 batch 80960/90000 	 loss 1.97 	 accuracy 0.06
# epoch 1/100 	 batch 81120/90000 	 loss 1.72 	 accuracy 0.50
# epoch 1/100 	 batch 81280/90000 	 loss 1.91 	 accuracy 0.19
# epoch 1/100 	 batch 81440/90000 	 loss 1.79 	 accuracy 0.38
# epoch 1/100 	 batch 81600/90000 	 loss 1.66 	 accuracy 0.44
# epoch 1/100 	 batch 81760/90000 	 loss 1.75 	 accuracy 0.44
# epoch 1/100 	 batch 81920/90000 	 loss 1.74 	 accuracy 0.75
# epoch 1/100 	 batch 82080/90000 	 loss 1.79 	 accuracy 0.44
# epoch 1/100 	 batch 82240/90000 	 loss 1.59 	 accuracy 0.56
# epoch 1/100 	 batch 82400/90000 	 loss 1.87 	 accuracy 0.44
# epoch 1/100 	 batch 82560/90000 	 loss 1.74 	 accuracy 0.19
# epoch 1/100 	 batch 82720/90000 	 loss 1.85 	 accuracy 0.38
# epoch 1/100 	 batch 82880/90000 	 loss 1.80 	 accuracy 0.38
# epoch 1/100 	 batch 83040/90000 	 loss 1.65 	 accuracy 0.38
# epoch 1/100 	 batch 83200/90000 	 loss 1.78 	 accuracy 0.44
# epoch 1/100 	 batch 83360/90000 	 loss 1.92 	 accuracy 0.25
# epoch 1/100 	 batch 83520/90000 	 loss 1.80 	 accuracy 0.50
# epoch 1/100 	 batch 83680/90000 	 loss 1.98 	 accuracy 0.31
# epoch 1/100 	 batch 83840/90000 	 loss 1.72 	 accuracy 0.44
# epoch 1/100 	 batch 84000/90000 	 loss 1.77 	 accuracy 0.44
# epoch 1/100 	 batch 84160/90000 	 loss 1.83 	 accuracy 0.44
# epoch 1/100 	 batch 84320/90000 	 loss 1.91 	 accuracy 0.12
# epoch 1/100 	 batch 84480/90000 	 loss 1.98 	 accuracy 0.31
# epoch 1/100 	 batch 84640/90000 	 loss 1.79 	 accuracy 0.31
# epoch 1/100 	 batch 84800/90000 	 loss 1.89 	 accuracy 0.50
# epoch 1/100 	 batch 84960/90000 	 loss 1.77 	 accuracy 0.31
# epoch 1/100 	 batch 85120/90000 	 loss 1.97 	 accuracy 0.19
# epoch 1/100 	 batch 85280/90000 	 loss 1.93 	 accuracy 0.38
# epoch 1/100 	 batch 85440/90000 	 loss 1.76 	 accuracy 0.44
# epoch 1/100 	 batch 85600/90000 	 loss 1.68 	 accuracy 0.56
# epoch 1/100 	 batch 85760/90000 	 loss 1.90 	 accuracy 0.19
# epoch 1/100 	 batch 85920/90000 	 loss 1.72 	 accuracy 0.38
# epoch 1/100 	 batch 86080/90000 	 loss 1.78 	 accuracy 0.50
# epoch 1/100 	 batch 86240/90000 	 loss 1.66 	 accuracy 0.44
# epoch 1/100 	 batch 86400/90000 	 loss 1.68 	 accuracy 0.50
# epoch 1/100 	 batch 86560/90000 	 loss 1.92 	 accuracy 0.38
# epoch 1/100 	 batch 86720/90000 	 loss 1.78 	 accuracy 0.38
# epoch 1/100 	 batch 86880/90000 	 loss 1.95 	 accuracy 0.25
# epoch 1/100 	 batch 87040/90000 	 loss 1.66 	 accuracy 0.44
# epoch 1/100 	 batch 87200/90000 	 loss 1.88 	 accuracy 0.31
# epoch 1/100 	 batch 87360/90000 	 loss 1.61 	 accuracy 0.38
# epoch 1/100 	 batch 87520/90000 	 loss 1.57 	 accuracy 0.56
# epoch 1/100 	 batch 87680/90000 	 loss 1.71 	 accuracy 0.31
# epoch 1/100 	 batch 87840/90000 	 loss 1.86 	 accuracy 0.38
# epoch 1/100 	 batch 88000/90000 	 loss 1.71 	 accuracy 0.50
# epoch 1/100 	 batch 88160/90000 	 loss 1.65 	 accuracy 0.38
# epoch 1/100 	 batch 88320/90000 	 loss 1.70 	 accuracy 0.31
# epoch 1/100 	 batch 88480/90000 	 loss 1.67 	 accuracy 0.56
# epoch 1/100 	 batch 88640/90000 	 loss 1.65 	 accuracy 0.44
# epoch 1/100 	 batch 88800/90000 	 loss 1.86 	 accuracy 0.31
# epoch 1/100 	 batch 88960/90000 	 loss 1.80 	 accuracy 0.31
# epoch 1/100 	 batch 89120/90000 	 loss 1.71 	 accuracy 0.50
# epoch 1/100 	 batch 89280/90000 	 loss 1.97 	 accuracy 0.25
# epoch 1/100 	 batch 89440/90000 	 loss 1.98 	 accuracy 0.19
# epoch 1/100 	 batch 89600/90000 	 loss 1.70 	 accuracy 0.38
# epoch 1/100 	 batch 89760/90000 	 loss 1.67 	 accuracy 0.56
# epoch 1/100 	 batch 89920/90000 	 loss 1.66 	 accuracy 0.62
# ********** train: epoch 1/100 	 accuracy 32.13% **********
# ********** test: epoch 1/100 	 accuracy 41.79% **********
# epoch 2/100 	 batch 160/90000 	 loss 1.77 	 accuracy 0.31
# epoch 2/100 	 batch 320/90000 	 loss 1.63 	 accuracy 0.44
# epoch 2/100 	 batch 480/90000 	 loss 1.87 	 accuracy 0.31
# epoch 2/100 	 batch 640/90000 	 loss 1.63 	 accuracy 0.56
# epoch 2/100 	 batch 800/90000 	 loss 1.88 	 accuracy 0.31
# epoch 2/100 	 batch 960/90000 	 loss 1.45 	 accuracy 0.69
# epoch 2/100 	 batch 1120/90000 	 loss 1.59 	 accuracy 0.50
# epoch 2/100 	 batch 1280/90000 	 loss 1.71 	 accuracy 0.50
# epoch 2/100 	 batch 1440/90000 	 loss 1.76 	 accuracy 0.31
# epoch 2/100 	 batch 1600/90000 	 loss 1.75 	 accuracy 0.56
# epoch 2/100 	 batch 1760/90000 	 loss 1.96 	 accuracy 0.25
# epoch 2/100 	 batch 1920/90000 	 loss 1.75 	 accuracy 0.25
# epoch 2/100 	 batch 2080/90000 	 loss 1.88 	 accuracy 0.25
# epoch 2/100 	 batch 2240/90000 	 loss 1.64 	 accuracy 0.50
# epoch 2/100 	 batch 2400/90000 	 loss 1.93 	 accuracy 0.31
# epoch 2/100 	 batch 2560/90000 	 loss 1.74 	 accuracy 0.44
# epoch 2/100 	 batch 2720/90000 	 loss 1.71 	 accuracy 0.44
# epoch 2/100 	 batch 2880/90000 	 loss 1.69 	 accuracy 0.50
# epoch 2/100 	 batch 3040/90000 	 loss 1.62 	 accuracy 0.56
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      23 acc = correct / y.shape[0]
#      24 correct_tot += correct
# ---> 25 loss.backward()
#      26 opt._step()
#      27 if i % 10 == 0:
#
# File pyvqnet\tensor\tensor.py:236, in pyvqnet.tensor.tensor.QTensor.backward()
#
# File pyvqnet\tensor\tensor.py:9204, in pyvqnet.tensor.tensor.backprop()
#
# File pyvqnet\tensor\tensor.py:9162, in pyvqnet.tensor.tensor.backprop_impl()
#
# File pyvqnet\qnn\quantumlayer.py:1533, in pyvqnet.qnn.quantumlayer.QuantumLayer.forward.lambda6()
#
# File pyvqnet\qnn\quantumlayer.py:1687, in pyvqnet.qnn.quantumlayer.QuantumLayer._grad_x()
#
# File pyvqnet\qnn\quantumlayer.py:3718, in pyvqnet.qnn.quantumlayer._fun_of_calc_x_grad()
#
# KeyboardInterrupt:

# %%
pv.utils.storage.save_parameters(model.state_dict(), "train13.model")

# %%
m = Model()
m.load_state_dict(pv.utils.storage.load_parameters("train13.model"))

# %%
m.eval()
X, Y = test_data.getdatas()
correct_tot = 0
for x, y in pv.data.data_generator(X, Y, batch_size=batch, shuffle=False):
    y_pred = model(x)
    correct_tot += sum(y_pred.argmax(1, False).to_numpy() == y)
acc = correct_tot / Y.shape[0]
print(f"********** eval: accuracy {100*acc:.2f}% **********")
# Out:
# ********** eval: accuracy 41.91% **********

# %%
pv.tensor.atan()
